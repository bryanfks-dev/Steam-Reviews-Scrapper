# %%
# Import required modules
# pandas is a module to work with dataframes
import pandas as pd

# configparser is a module to work with configuration files
import configparser

# %%
# config is an object of RawConfigParser class
config = configparser.RawConfigParser()

# Read the configuration file
config.read("app.properties")
# Out:
# ['app.properties']

# %%
# csv_file_path is a variable that contains the path of the CSV file that the program will create
# to store the result of scraped data
#
# To update the path of the CSV file path, update the value of csv.path in app.properties file
csv_file_path: str = config.get("CSVSection", "csv.path")

# %%
# Read the CSV file and store the data in a dataframe
df = pd.read_csv(csv_file_path)

# Print the csv file as a dataframe
df
# Out:
#                                                Review     Label
# 0                             barang ori cepat proses   neutral
# 1                           packing aman unit kondisi   neutral
# 2                                               bagus   neutral
# 3   jual responsif produk terima sesuai pesan reco...  positive
# 4             barang original bagus cepat rekomendasi  positive
# 5   packingnya aman barang segel dapet diskon juta...   neutral
# 6                                  barang mulus darat   neutral
# 7                                                  ok  positive
# 8   barang terima normal ios update moga lancar te...   neutral
# 9   barang sdh tp test diupdate seller responsif k...   neutral
# 10  barang bagus bgt warna black tawan elegan laya...  positive
# 11                                 test minggu aman b   neutral
# 12  barang asli digimap kirim sy pilih pickup kena...  positive
# 13                              barang nya aman cacat   neutral
# 14   barang sesuai sellernya fast respon mantap pokok   neutral
# 15                         barang original segel ibox  positive
# 16                                             mantul   neutral
# 17                                        terimakasih   neutral
# 18                                               joss   neutral
# 19         barang resmi segel mantapp thankyou seller   neutral
# 20  terima kasih barang bagus kirim cepat layan ba...  positive
# 21  revisimantapp kasih health batre hp jalan kend...   neutral
# 22                           good quality good seller  positive
# 23                                      barang kereen   neutral
# 24                                      barang muluss   neutral
# 25                                    cepat responnya   neutral
# 26                                     barang bagusss   neutral
# 27                          sesuai bagus mulus banget   neutral
# 28                                 barang sesuai aman   neutral
# 29                                          bagus gan   neutral
# 30         pesan sesuai barang aman seller layan muas   neutral
# 31  makasih kak barang terima pesan sesuai barang ...   neutral
# 32  seller ramah responsif toko recommended beli p...  positive
# 33  pesan sesuai barang aman seller ramah packinga...  positive
# 34  kualitas barang barang sesuai pesan proses ord...   neutral
# 35  barang original sinyal aman imei daftar kemenp...  positive
# 36  fungsi barang mulus jual ramah banget packagin...   neutral
# 37  barang mulus fungsi jual ramah banget proses p...   neutral
# 38  kualitas barang okebarang oriseller ramah pesa...   neutral
# 39                                    barang bagussss   neutral
# 40                                  barngnya kereeenn   neutral
# 41           good beli iphone recomended seller ramah  positive
# 42        barang sampe yaa kak pesan sesuai unit aman   neutral
# 43         bagus aman sesuai imei aktif garansi resmi   neutral
# 44  barang original imei daftar kemenperin imei da...  positive
# 45  barang original sinyal aman fungsi imei daftar...  positive
